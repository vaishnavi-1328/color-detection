# %% [markdown]
# # Name : Vaishnavi S
# # TASK: Colors detection of a picture
#
# ![image.png](attachment:image.png)

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import cv2 
from collections import Counter
import pandas as pd
from skimage.color import rgb2lab, deltaE_cie76
import os

# %matplotlib inline
image = cv2.imread('E:/pics/Image0012.jpg')
print("The type of this input is {}".format(type(image)))
print("Shape: {}".format(image.shape))
plt.imshow(image)
image=image.reshape(image.shape[0]*image.shape[1],3)
# Out:
# The type of this input is <class 'numpy.ndarray'>
# Shape: (1600, 1200, 3)

# %%
kmeans=KMeans(n_clusters=10)
s=kmeans.fit(image)
labels=kmeans.labels_
print(labels)
labels=list(labels)
# Out:
# [4 4 4 ... 4 4 4]

# %%
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# plt.imshow(image)
centroid=kmeans.cluster_centers_
print(centroid)
# Out:
# [[166.60192369 170.95021909 167.99001817]
#  [ 85.12402669  91.39183481  62.41545201]
#  [215.78821848 214.83196844 208.11219038]
#  [ 34.1906802   30.76030693  31.17012229]
#  [247.58547569 251.40508567 248.95021878]
#  [131.42844236 139.82485759 143.85323627]
#  [ 64.79891157  74.28183387  37.35151219]
#  [191.35616432 194.45038938 190.9638355 ]
#  [ 53.09583708  65.81973373 101.34161017]
#  [107.41356113 111.62030259 105.85699014]]

# %%
percent=[]
for i in range(len(centroid)):
    j=labels.count(i)
    j=j/(len(labels))
    percent.append(j)
print(percent)
# Out:
# [0.09750989583333333, 0.18591875, 0.170190625, 0.032532291666666664, 0.1060578125, 0.06050572916666667, 0.13096458333333333, 0.1171953125, 0.019148958333333334, 0.07997604166666666]

# %%
plt.pie(percent,colors=np.array(centroid/255),labels=np.arange(len(centroid)))
plt.show()
